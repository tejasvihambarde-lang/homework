# %%
name = "Tejasvi"
print(name)
print(type(name))
print(id(name))
# Out:
# Tejasvi
# <class 'str'>
# 2272725930688

# %%
city = "Beed"
print(city)
print(type(city))
print(id(city))
# Out:
# Beed
# <class 'str'>
# 2272723131856

# %%
colours = "red","blue","yellow"
print(colours)
print(type(colours))
print(id(colours))
# Out:
# ('red', 'blue', 'yellow')
# <class 'tuple'>
# 2272725897104

# %%
print(type(name))
print(type(city))
print(type(colours))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'tuple'>

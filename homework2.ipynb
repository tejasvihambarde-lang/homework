# %%
numbers = 20,13,45,65
print(numbers)
print(type(numbers))
print(id(numbers))
# Out:
# (20, 13, 45, 65)
# <class 'tuple'>
# 1643512323568

# %%
number = 20
print(number)
print(type(number))
print(id(number))
# Out:
# 20
# <class 'int'>
# 140734959118040

# %%
number = 34.56
print(number)
print(type(number))
print(id(number))
# Out:
# 34.56
# <class 'float'>
# 1643509487536

# %%
total =10+30
print(total)
print(type(total))
print(id(total))
# Out:
# 40
# <class 'int'>
# 140734959118680

# %%
number =20-10
print(number)
print(type(number))
print(id(number))
# Out:
# 10
# <class 'int'>
# 140734959117720

# %%
a = 10
b = 20
print(a*b)
# Out:
# 200

# %%
print(type(a*b))
# Out:
# <class 'int'>

# %%
print(id(a*b))
# Out:
# 140734959123800

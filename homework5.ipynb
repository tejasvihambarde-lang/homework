# %%
name = True
print(name)
print(type(name))
print(id(name))
# Out:
# True
# <class 'bool'>
# 140734958217984

# %%
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
print(id(a))
print(id(b))
# Out:
# 140734959117720
# 140734959118040
